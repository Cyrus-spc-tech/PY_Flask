# %%
a=input("str")
# a[::-1]
# without slicing
length=len(a) 
for i in a :
    print ()
# Out:
# 'kjhgfdsa'

# %%
a=[5,6,7,6,8,9,4,3,5]
b=set(a)
b
# preventing order
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
# secongd largest no

# %%
# count freq of char
